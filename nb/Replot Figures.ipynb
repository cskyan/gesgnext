# %% [markdown]
# # Setting

# %%
import os
import numpy as np
from bionlp.util import io, func, plot

# %matplotlib inline

DATA_PATH = '../../data'
plot.MON = True

# %%
fig_cache = 'violin.npz'
fig_data = io.read_npz(os.path.join(DATA_PATH, fig_cache))
# plot.plot_data(fig_data, title='')

# %%
plot.plot_violin(fig_data['data'], title='', fmt='pdf', xlabel='GEO Collection', ylabel='-log10(Adjusted P-Value)', labels=fig_data['labels'], groups=fig_data['groups'], ref_lines={'y':[-np.log10(0.05)]}, log=-1, sns_inner='box', sns_bw=.3, ax_ylim=[-2, 11])
# Out:
# /home/shankai/source/py/bionlp/util/plot.py:530: RuntimeWarning: invalid value encountered in log10
#   df[xlabel], df[ylabel], df['groups'] = df[xlabel].astype('category'), kwargs['log'] * np.log10(df[ylabel].astype('float')) if (kwargs.setdefault('log', 0) != 0) else df[ylabel].astype('float'), df['groups'].astype('category')
